# %% [markdown]
# # Films

# %%
df = pd.read_csv("/content/drive/MyDrive/RecSysDatasets/RecSys_kaggle_dataset/movies_metadata.csv")
df.head(2)
# Out:
# <ipython-input-196-35d20270fd96>:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/drive/MyDrive/RecSysDatasets/RecSys_kaggle_dataset/movies_metadata.csv")
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
#
#                                homepage    id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story   862  tt0114709                en
# 1                                   NaN  8844  tt0113497                en
#
#   original_title                                           overview  ...  \
# ...

# %%
keywords = pd.read_csv("/content/drive/MyDrive/RecSysDatasets/RecSys_kaggle_dataset/keywords.csv")
keywords['keywords'].head(2)
# Out:
# 0    [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1    [{'id': 10090, 'name': 'board game'}, {'id': 1...
# Name: keywords, dtype: object

# %%
credits = pd.read_csv("/content/drive/MyDrive/RecSysDatasets/RecSys_kaggle_dataset/credits.csv")
credits.head(2)
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
#
#                                                 crew    id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...   862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...  8844

# %%
df = df[['id', 'title', 'genres', 'overview', 'production_companies', 'production_countries', 'release_date', 'runtime', 'poster_path', 'vote_average', 'vote_count']]

# %%
df.shape
# Out:
# (45466, 11)

# %%
df.columns
# Out:
# Index(['id', 'title', 'genres', 'overview', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'poster_path',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
df.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                                 production_companies  \
# ...

# %%
df.isna().sum()
# Out:
# id                        0
# title                     6
# genres                    0
# overview                954
# production_companies      3
# production_countries      3
# release_date             87
# runtime                 263
# poster_path             386
# vote_average              6
# vote_count                6
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44128 entries, 0 to 45465
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    44128 non-null  object
#  1   title                 44128 non-null  object
#  2   genres                44128 non-null  object
#  3   overview              44128 non-null  object
#  4   production_companies  44128 non-null  object
#  5   production_countries  44128 non-null  object
#  6   release_date          44128 non-null  object
#  7   runtime               44128 non-null  float64
#  8   poster_path           44128 non-null  object
#  9   vote_average          44128 non-null  float64
#  10  vote_count            44128 non-null  float64
# dtypes: float64(3), object(8)
# memory usage: 4.0+ MB

# %%
df = df.astype({'id': 'int64', 'title': 'str'})

# %%
df = df.merge(credits, on='id')

# %%
df = df.merge(keywords, on='id')

# %%
df.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                                 production_companies  \
# ...

# %%
def get_director(x):
    for i in x:
        if i['job'] == 'Director':
            return i['name']
    return np.nan

# %%
def get_list(x):
    if isinstance(x, list):
        names = [i['name'] for i in x]
        if len(names) > 3:
            names = names[:3]
        return names
    return np.nan

# %%
from ast import literal_eval

features = ['cast', 'crew', 'keywords', 'genres']
for feature in features:
    df[feature] = df[feature].apply(literal_eval)

# %%
df['director'] = df['crew'].apply(get_director)

features = ['cast', 'keywords', 'genres']
for feature in features:
  df[feature] = df[feature].apply(get_list)

# %%
productions = ['production_companies', 'production_countries']
df_cleaned = df.copy()

for prod in productions:
  df_cleaned[prod] = df[prod].apply(literal_eval)
  df_cleaned[prod] = df_cleaned[prod].apply(get_list)

# %%
df_cleaned = df_cleaned.drop_duplicates(subset='title')

# %%
df_cleaned.head()
# Out:
#       id                        title                        genres  \
# 0    862                    Toy Story   [Animation, Comedy, Family]
# 1   8844                      Jumanji  [Adventure, Fantasy, Family]
# 2  15602             Grumpier Old Men             [Romance, Comedy]
# 3  31357            Waiting to Exhale      [Comedy, Drama, Romance]
# 4  11862  Father of the Bride Part II                      [Comedy]
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                                 production_companies  \
# 0                          [Pixar Animation Studios]
# 1  [TriStar Pictures, Teitler Film, Interscope Co...
# 2                     [Warner Bros., Lancaster Gate]
# ...

# %%
def get_info(data, col, is_str=True):
  if is_str:
    data[f'count_{col}'] = data[col].apply(lambda x: len(str(x).split()))
  else:
    data[f'count_{col}'] = data[col].apply(lambda x: len(x))
  lengths = list(data[f'count_{col}'])
  print(f"Number of {col}:",len(lengths),
        "\nAverage word count", np.average(lengths),
        "\nMinimum word count", min(lengths),
        "\nMaximum word count", max(lengths))

# %%
df_cleaned.columns
# Out:
# Index(['id', 'title', 'genres', 'overview', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'poster_path',
#        'vote_average', 'vote_count', 'cast', 'keywords', 'director',
#        'count_title'],
#       dtype='object')

# %%
get_info(df_cleaned, 'title')
# Out:
# Number of title: 41013
# Average word count 3.0689293638602395
# Minimum word count 1
# Maximum word count 20
# <ipython-input-158-e02a07e7cb97>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'count_{col}'] = data[col].apply(lambda x: len(str(x).split()))

# %%
get_info(df_cleaned, 'genres', is_str=False)
# Out:
# Number of genres: 41013
# Average word count 1.9041523419403603
# Minimum word count 0
# Maximum word count 3
# <ipython-input-158-e02a07e7cb97>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'count_{col}'] = data[col].apply(lambda x: len(x))

# %%
df_cleaned = df_cleaned[df_cleaned['count_genres'] > 0]

# %%
get_info(df_cleaned, 'overview')
# Out:
# Number of overview: 39173
# Average word count 55.171342506318126
# Minimum word count 0
# Maximum word count 187
# <ipython-input-158-e02a07e7cb97>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'count_{col}'] = data[col].apply(lambda x: len(str(x).split()))

# %%
df_cleaned = df_cleaned[df_cleaned['count_overview'] > 3]

# %%
cols = ['production_companies',
       'production_countries', 'cast', 'keywords']

# %%
for col in cols:
  get_info(df_cleaned, col, is_str=False)
# Out:
# Number of production_companies: 39033
# Average word count 1.3852893705326261
# Minimum word count 0
# Maximum word count 3
# Number of production_countries: 39033
# Average word count 1.1032459713575693
# Minimum word count 0
# Maximum word count 3
# Number of cast: 39033
# Average word count 2.8100581559193505
# Minimum word count 0
# Maximum word count 3
# Number of keywords: 39033
# Average word count 1.7789050290779598
# Minimum word count 0
# Maximum word count 3

# %%
for col in cols:
  df_cleaned = df_cleaned[df_cleaned[f'count_{col}'] > 0]

# %%
df_cleaned.shape
# Out:
# (23748, 21)

# %%
df_cleaned.drop(['count_title', 'count_genres', 'count_overview', 'count_production_companies', 'count_production_countries', 'count_cast', 'count_keywords'], axis=1, inplace=True)

# %%
df_cleaned['release_date'] = pd.to_datetime(df_cleaned['release_date'], errors='coerce')

invalid_dates = df_cleaned['release_date'].isna().sum()
print(f"Количество неверных дат: {invalid_dates}")
# Out:
# Количество неверных дат: 0

# %%
df_cleaned.drop('poster_path', axis=1, inplace=True)

# %%
df_cleaned.head(3)
# Out:
#       id             title                        genres  \
# 0    862         Toy Story   [Animation, Comedy, Family]
# 1   8844           Jumanji  [Adventure, Fantasy, Family]
# 2  15602  Grumpier Old Men             [Romance, Comedy]
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
#
#                                 production_companies  \
# 0                          [Pixar Animation Studios]
# 1  [TriStar Pictures, Teitler Film, Interscope Co...
# 2                     [Warner Bros., Lancaster Gate]
#
#          production_countries release_date  runtime  vote_average  vote_count  \
# 0  [United States of America]   1995-10-30     81.0           7.7      5415.0
# 1  [United States of America]   1995-12-15    104.0           6.9      2413.0
# ...

# %%
df_cleaned.dropna(inplace=True)

# %%
df_cleaned.shape
# Out:
# (23701, 13)

# %%
df_cleaned_types = df_cleaned.astype({'runtime': 'int64', 'vote_count': 'int64'})

# %%
df_cleaned_types.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23701 entries, 0 to 45236
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    23701 non-null  int64
#  1   title                 23701 non-null  object
#  2   genres                23701 non-null  object
#  3   overview              23701 non-null  object
#  4   production_companies  23701 non-null  object
#  5   production_countries  23701 non-null  object
#  6   release_date          23701 non-null  datetime64[ns]
#  7   runtime               23701 non-null  int64
#  8   vote_average          23701 non-null  float64
#  9   vote_count            23701 non-null  int64
#  10  cast                  23701 non-null  object
#  11  keywords              23701 non-null  object
#  12  director              23701 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(8)
# memory usage: 2.5+ MB

# %%
cols_to_json = ['genres', 'production_companies', 'production_countries', 'cast', 'keywords']

for col in cols_to_json:
  df_cleaned_types[col] = df_cleaned_types[col].apply(json.dumps)

df_cleaned_types.head(3)
# Out:
#       id             title                              genres  \
# 0    862         Toy Story   ["Animation", "Comedy", "Family"]
# 1   8844           Jumanji  ["Adventure", "Fantasy", "Family"]
# 2  15602  Grumpier Old Men               ["Romance", "Comedy"]
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
#
#                                 production_companies  \
# 0                        ["Pixar Animation Studios"]
# 1  ["TriStar Pictures", "Teitler Film", "Intersco...
# 2                 ["Warner Bros.", "Lancaster Gate"]
#
#            production_countries release_date  runtime  vote_average  \
# 0  ["United States of America"]   1995-10-30       81           7.7
# 1  ["United States of America"]   1995-12-15      104           6.9
# 2  ["United States of America"]   1995-12-22      101           6.5
#
# ...

# %%
df_cleaned_types.shape
# Out:
# (23701, 13)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - v - the number of votes for the movie;
# - m - the minimum votes required to be listed in the chart;
# - R - the average rating of the movie;
# - C - the mean vote across the whole report

# %%
m = df_cleaned_types['vote_count'].quantile(0.96)
C = df_cleaned_types['vote_average'].mean()
def weighted_rating(x, m=m, C=C):
    v = x['vote_count']
    R = x['vote_average']
    return round((v/(v+m) * R) + (m/(m+v) * C), 3)

# %%
df_cleaned_types['weight_rating'] = df_cleaned_types.apply(weighted_rating, axis=1)

# %%
df_cleaned_types.head()
# Out:
#       id                        title                              genres  \
# 0    862                    Toy Story   ["Animation", "Comedy", "Family"]
# 1   8844                      Jumanji  ["Adventure", "Fantasy", "Family"]
# 2  15602             Grumpier Old Men               ["Romance", "Comedy"]
# 3  31357            Waiting to Exhale      ["Comedy", "Drama", "Romance"]
# 4  11862  Father of the Bride Part II                          ["Comedy"]
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                                 production_companies  \
# 0                        ["Pixar Animation Studios"]
# 1  ["TriStar Pictures", "Teitler Film", "Intersco...
# ...

# %%
df_cleaned_types.to_csv('dataset_23k_v2.csv', index=False)

# %% [markdown]
# # Ratings

# %%
df_films = pd.read_csv("/content/drive/MyDrive/RecSysDatasets/dataset_23k.csv")
df_films.head(3)
# Out:
#       id             title                              genres  \
# 0    862         Toy Story   ["Animation", "Comedy", "Family"]
# 1   8844           Jumanji  ["Adventure", "Fantasy", "Family"]
# 2  15602  Grumpier Old Men               ["Romance", "Comedy"]
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
#
#                                 production_companies  \
# 0                        ["Pixar Animation Studios"]
# 1  ["TriStar Pictures", "Teitler Film", "Intersco...
# 2                 ["Warner Bros.", "Lancaster Gate"]
#
#            production_countries release_date  runtime  vote_average  \
# 0  ["United States of America"]   1995-10-30       81           7.7
# 1  ["United States of America"]   1995-12-15      104           6.9
# 2  ["United States of America"]   1995-12-22      101           6.5
#
# ...

# %%
ratings = pd.read_csv("/content/drive/MyDrive/RecSysDatasets/RecSys_kaggle_dataset/ratings.csv")
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
ratings.shape
# Out:
# (26024289, 4)

# %%
new_ratings = ratings[ratings['movieId'].isin(df_films['id'])]
new_ratings.shape
# Out:
# (10000020, 4)

# %%
new_ratings.to_csv('new_ratings.csv', index=False)
